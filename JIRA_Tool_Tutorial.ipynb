# %% [markdown]
# ## JIRA_TOOL_TUTORIAL

# %% [markdown]
# ![image.png](attachment:903251e4-8db7-47d0-930e-df81ca6b7f41.png)

# %% [markdown]
# ![image.png](attachment:bfbdf101-7288-4df3-b098-9e294eff7ae7.png)

# %% [markdown]
# ![image.png](attachment:025df56b-d0bb-4049-aa5f-fc92f00c5450.png)

# %% [markdown]
# ![image.png](attachment:1eb99065-b10a-488d-8870-17b4bdb79430.png)

# %% [markdown]
# ![image.png](attachment:7518cbe5-c1c0-4d85-a7ca-e1a3f4f35a00.png)

# %% [markdown]
# ![image.png](attachment:f235d329-9ada-4b69-b425-d7a2927414a3.png)

# %% [markdown]
# ![image.png](attachment:935a9291-2b5d-49ac-a94a-b00f40db459a.png)

# %% [markdown]
# ![image.png](attachment:9a147826-6d75-4f98-974b-91e17e29435e.png)

# %% [markdown]
# ![image.png](attachment:ecf14e61-6bfe-49a1-9bd7-84d223a4bb8a.png)
